# %% [markdown]
# <a href="https://colab.research.google.com/github/SriBhumika06/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 02:59:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   197MB/s    in 0.4s
#
# 2024-03-31 02:59:27 (197 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11631  1608.03585v1  We develop a framework for warm-starting Bayes...  stat
# 14280  1605.07689v3  We present a Communication-efficient Surrogate...  stat
# 21115  1708.02153v1  In this work we focus on the following questio...    cs
# 29075  1708.03763v2  We have developed a deep learning network for ...    cs
# 21862   1401.8066v2  This paper presents a general vector-valued re...  stat
# ...             ...                                                ...   ...
# 13741   1407.0008v1  Navigating networked robot swarms often requir...    cs
# 37007  1603.01581v4  Cloud computing involves complex technical and...    cs
# 22351  1603.02160v2  Kernel methods are one of the mainstays of mac...  stat
# 23047  1802.07481v2  Convex sparsity-inducing regularizations are u...  stat
# 25877  1512.01891v1  This paper proposes to learn high-performance ...    cs
#
#                                                    title  year  \
# 11631                Warm Starting Bayesian Optimization  2016
# 14280  Communication-Efficient Distributed Statistica...  2016
# 21115  A Characterization of Monotone Influence Measu...  2017
# 29075  Flower Categorization using Deep Convolutional...  2017
# 21862  A Unifying Framework in Vector-valued Reproduc...  2014
# ...                                                  ...   ...
# 13741  Navigating Robot Swarms Using Collective Intel...  2014
# 37007               Causal inference for cloud computing  2016
# 22351             Bayesian Learning of Kernel Embeddings  2016
# 23047        Dual Extrapolation for Faster Lasso Solvers  2018
# 25877  Sparsifying Neural Network Connections for Fac...  2015
#
#                                                 keywords
# 11631  [framework, optimization, optimization, optimi...
# 14280  [communication, efficient, surrogate, likeliho...
# 21115  [following, important, determining, datapoint,...
# 29075  [developed, classification, different, differe...
# 21862  [reproducing, framework, functional, dependenc...
# ...                                                  ...
# 13741  [navigating, networked, environment, destinati...
# 37007  [computing, technical, economical, interaction...
# 22351  [mainstays, challenging, heuristics, particula...
# 23047  [regularizations, ubiquitous, dimension, diffe...
# 25877  [performance, connections, recognition, iterat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11631    [framework, optimization, optimization, optimi...
# 14280    [communication, efficient, surrogate, likeliho...
# 21115    [following, important, determining, datapoint,...
# 29075    [developed, classification, different, differe...
# 21862    [reproducing, framework, functional, dependenc...
#                                ...
# 10797    [statistical, iterative, regularization, algor...
# 22764    [interesting, molecules, infeasible, throughpu...
# 30250    [introduce, significantly, character, combinat...
# 20226    [hierarchies, applications, navigation, organi...
# 11909    [canonical, completion, completion, structure,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8942 words.
# Out of those 4572 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="362d6c81-d1d0-40ea-adcd-91ec15ed020c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("362d6c81-d1d0-40ea-adcd-91ec15ed020c")) {                    Plotly.newPlot(                        "362d6c81-d1d0-40ea-adcd-91ec15ed020c",                        [{"x":["derivative","sequences","different","information","stochastic","statistical","collection","calculation","optimizing","simulator","iteration","recommend","functions","decisions","optimization","collected","framework","objective","metamodel","algorithms","approximation","procedure","experiments","intervals","properties","facilitates","likelihood","construction","controlled","regularized","estimator","distribution","computational","posterior","significantly","confidence","inference","converges","distributed","efficiency","communication","estimation","theoretical","efficient","averaging","dimensional","surrogate","influence","classification","effective","reasonable","important","knowledge","characterization","following","corresponds","determining","classifier","underlying","importance","naturally","requirement","departing","desirable","datapoint","labelling","explanations","convolutional","applications","university","implemented","extremely","developed","parameters","architectures","googlenet","performance","respectively","segmentation","categorization","basically","accuracies","structured","demonstrate","equations","generalizes","dependency","challenging","encompasses","providing","particular","regularization","laplacian","empirical","functional","sequential","reproducing","formulation","competitiveness","quadratic","supervised","approaches","recognition","achieving","environments","generalization","auxiliary","architecture","environment","diversity","attentional","generalize","simulation","processes","substantial","distractors","improvement","interactive","interaction","selection","reinforcement","passively","mechanism","demonstration","generalizing","difficult","manipulator","adaptation","multitask","sensorimotor","typically","nonconvex","formulated","regression","numerical","benchmark","constraint","minimization","simulations","algorithm","alternating","considering","econometrics","considered","dimension","literature","reduction","orthogonality","processing","performing","organised","construct","ensembling","challenge","experience","traditional","recognised","homogeneous","longitudinal","relationships","publications","partnership","databases","comparison","innovation","unlabelled","observational","identifying","simulated","associations","conditions","fundamentally","impractical","ubiquitous","inherently","rightarrow","detection","disadvantages","generally","dependencies","techniques","attributed","downstream","applicable","embedding","inductive","attribute","transductive","prediction","estimating","representation","sensitive","morphology","including","transducers","solutions","acquiring","eventually","reconstructions","considerations"],"y":[5,112,690,685,142,165,61,17,45,7,43,9,222,75,321,71,572,161,0,582,112,113,626,15,181,20,64,69,30,37,22,227,285,39,264,40,230,34,98,160,70,205,159,396,19,183,18,72,479,248,34,351,363,32,74,33,41,161,110,79,57,27,3,25,2,18,22,382,418,11,105,55,187,248,135,7,884,93,194,25,9,28,104,562,30,34,39,261,4,90,261,75,13,140,42,76,8,86,0,29,209,446,390,78,80,119,27,253,129,50,13,51,80,107,45,2,126,42,101,142,114,3,121,15,17,138,3,65,9,8,113,9,32,123,88,211,108,57,39,809,27,76,1,100,63,116,85,3,302,72,4,95,2,152,37,167,5,16,2,68,7,1,72,146,10,3,7,65,58,7,148,4,13,11,16,4,353,7,72,52,402,11,8,51,117,16,32,6,207,69,371,58,20,227,5,149,11,14,14,7],"type":"bar"},{"x":["derivative","sequences","different","information","stochastic","statistical","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4572,), (4572, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4235294117647059);'>Knowledge</span> <span style=''>based</span> <span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.6615384615384614);'>Answering</span> <span style=''>with</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.30357142857142866);'>Understanding</span> <span style=''>and</span> <span style=''>Advanced</span> <span style='background-color:rgba(0, 255, 0, 0.7808219178082192);'>Reasoning</span> <br/><br/><span style=''>This</span> <span style=''>research</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>hypothesized</span> <span style=''>that</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>solution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>known</span> <span style=''>as</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.30357142857142866);'>Understanding</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7808219178082192);'>Reasoning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7064220183486238);'>Intelligence</span> <span style=''>(NaLURI)</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.30357142857142866);'>understanding</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3947368421052633);'>representation</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>formalism</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>ontological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7808219178082192);'>reasoning</span> <span style=''>approach</span> <span style=''>with</span> <span style=''>advanced</span> <span style=''>features</span> <span style=''>will</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>problems</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compromising</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>practicality</span> <span style=''>factors</span> <span style=''>1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restriction</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>question</span> <span style=''>and</span> <span style=''>response</span> <span style=''>and</span> <span style=''>2)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitation</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>across</span> <span style=''>domains</span> <span style=''>and</span> <span style=''>to</span> <span style=''>real</span> <span style=''>life</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>text</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Recovering</span> <span style=''>Latent</span> <span style=''>Signals</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Measurements</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Prior</span> <br/><br/><span style=''>In</span> <span style=''>sensing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>sensors</span> <span style=''>cannot</span> <span style=''>always</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>at</span> <span style=''>the</span> <span style=''>required</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style=''>they</span> <span style=''>can</span> <span style=''>only</span> <span style=''>acquire</span> <span style=''>a</span> <span style=''>blurred</span> <span style=''>version</span> <span style=''>of</span> <span style=''>it</span> <span style=''>due</span> <span style=''>the</span> <span style=''>sensors</span> <span style=''>transfer</span> <span style=''>function</span> <span style=''>To</span> <span style=''>recover</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>when</span> <span style=''>only</span> <span style=''>noisy</span> <span style=''>mixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>(GPMM)</span> <span style=''>which</span> <span style=''>models</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>signal</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>such</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>to</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>noisy</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>how</span> <span style=''>to</span> <span style=''>train</span> <span style=''>GPMM</span> <span style=''>that</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>GP</span> <span style=''>and</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>signal</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>Eigenspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>using</span> <span style=''>Random</span> <span style=''>Signals</span> <br/><br/><span style=''>We</span> <span style=''>focus</span> <span style=''>in</span> <span style=''>this</span> <span style=''>work</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>eigenvectors</span> <span style=''>of</span> <span style=''>any</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style=''>signals</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>we</span> <span style=''>only</span> <span style=''>need</span> <span style=''>k</span> <span style=''>such</span> <span style=''>signals</span> <span style=''>to</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>exactly</span> <span style=''>recover</span> <span style=''>as</span> <span style=''>many</span> <span style=''>of</span> <span style=''>the</span> <span style=''>smallest</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>eigenvectors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regardless</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>address</span> <span style=''>key</span> <span style=''>issues</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>concepts</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>using</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximated</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>also</span> <span style=''>propose</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>both</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>eigenspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kth</span> <span style=''>smallest</span> <span style='background-color:rgba(255, 0, 0, 0.7037037037037037);'>eigenvalue</span> <span style=''>lambda</span> <span style=''>k</span> <span style=''>The</span> <span style=''>latter</span> <span style=''>proves</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>locally</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Train</span> <span style=''>longer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>better</span> <span style=''>closing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>gap</span> <span style=''>in</span> <span style=''>large</span> <span style=''>batch</span> <span style=''>training</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Background</span> <span style=''>Deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>trained</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>or</span> <span style=''>one</span> <span style=''>of</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>These</span> <span style=''>methods</span> <span style=''>update</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>using</span> <span style=''>their</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style=''>a</span> <span style=''>small</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>observed</span> <span style=''>that</span> <span style=''>when</span> <span style=''>using</span> <span style=''>large</span> <span style=''>batch</span> <span style=''>sizes</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>persistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>degradation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>gap</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomena</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identifying</span> <span style=''>the</span> <span style=''>origin</span> <span style=''>of</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>and</span> <span style=''>closing</span> <span style=''>it</span> <span style=''>had</span> <span style=''>remained</span> <span style=''>an</span> <span style=''>open</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Contributions</span> <span style=''>We</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>high</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>training</span> <span style=''>phase</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>the</span> <span style=''>weight</span> <span style=''>distance</span> <span style=''>from</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>grows</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>logarithmically</span> <span style=''>with</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>weight</span> <span style=''>updates</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>propose</span> <span style=''>a</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13046594982078852)
# 	representation (0.13297491039426523)
# 	information (0.24551971326164876)
# 	segmentation (0.06953405017921147)
# 	architecture (0.0906810035842294)
# 	knowledge (0.13010752688172042)
# 	different (0.24731182795698925)
# 	detection (0.12652329749103944)
# 	convolutional (0.13691756272401434)
# 	recognition (0.13978494623655913)
#
# Some Statistics words are:
# 	variational (0.10149253731343283)
# 	theoretical (0.14427860696517414)
# 	variables (0.13482587064676618)
# 	statistical (0.15323383084577114)
# 	estimation (0.1701492537313433)
# 	algorithm (0.39154228855721396)
# 	distribution (0.18407960199004975)
# 	dimensional (0.18258706467661692)
# 	inference (0.2044776119402985)
# 	regression (0.1845771144278607)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73d2727c-fe25-4816-a4d9-fdab43c5f95b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73d2727c-fe25-4816-a4d9-fdab43c5f95b")) {                    Plotly.newPlot(                        "73d2727c-fe25-4816-a4d9-fdab43c5f95b",                        [{"x":["derivative","sequences","different","information","stochastic","statistical","collection","calculation","optimizing","simulator","iteration","recommend","functions","decisions","optimization","collected","framework","objective","metamodel","algorithms","approximation","procedure","experiments","intervals","properties","facilitates","likelihood","construction","controlled","regularized","estimator","distribution","computational","posterior","significantly","confidence","inference","converges","distributed","efficiency","communication","estimation","theoretical","efficient","averaging","dimensional","surrogate","influence","classification","effective","reasonable","important","knowledge","characterization","following","corresponds","determining","classifier","underlying","importance","naturally","requirement","departing","desirable","datapoint","labelling","explanations","convolutional","applications","university","implemented","extremely","developed","parameters","architectures","googlenet","performance","respectively","segmentation","categorization","basically","accuracies","structured","demonstrate","equations","generalizes","dependency","challenging","encompasses","providing","particular","regularization","laplacian","empirical","functional","sequential","reproducing","formulation","competitiveness","quadratic","supervised","approaches","recognition","achieving","environments","generalization","auxiliary","architecture","environment","diversity","attentional","generalize","simulation","processes","substantial","distractors","improvement","interactive","interaction","selection","reinforcement","passively","mechanism","demonstration","generalizing","difficult","manipulator","adaptation","multitask","sensorimotor","typically","nonconvex","formulated","regression","numerical","benchmark","constraint","minimization","simulations","algorithm","alternating","considering","econometrics","considered","dimension","literature","reduction","orthogonality","processing","performing","organised","construct","ensembling","challenge","experience","traditional","recognised","homogeneous","longitudinal","relationships","publications","partnership","databases","comparison","innovation","unlabelled","observational","identifying","simulated","associations","conditions","fundamentally","impractical","ubiquitous","inherently","rightarrow","detection","disadvantages","generally","dependencies","techniques","attributed","downstream","applicable","embedding","inductive","attribute","transductive","prediction","estimating","representation","sensitive","morphology","including","transducers","solutions","acquiring","eventually","reconstructions","considerations","discusses","investigation","realistic","reconstruction","sophisticated","systematic","describing","capturing","carefully","generating","evidences","optimally","approximate","perfectly","structure","constructed","combinatorial","relaxation","classical","interesting","correspondences","continuous","representations","formulate","transaction","attributes","personalization","relational","characteristics","integrate","demographic","inferring","extension","nonparametric","specified","denoising","generative","recommendations","advancements","collaborative","interested","analytical","instances","technologies","corrupted","reconstruct","contribution","recommender","filtering","situations","practical","interdependency","effectively","dimensions", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	metamodel
# 	competitiveness
# 	davenport
# 	degeneracy
# 	blockmodel
# 	overfitted
# 	nonparametrics
# 	medication
# 	attitudes
# 	archetypal
# 	shrinking
# 	robustification
# 	disclosure
# 	dependences
# 	confounders
# 	ingenious
# 	deterioration
# 	distributedly
# 	ergodicity
# 	differentiability
# Some words which never appear in Statistics papers:
# 	googlenet
# 	distractors
# 	passively
# 	sensorimotor
# 	morphology
# 	transducers
# 	evidences
# 	interdependency
# 	attentive
# 	competent
# 	substructures
# 	multiobjective
# 	boundedly
# 	solomonoff
# 	prolonged
# 	formalisms
# 	discourse
# 	pragmatics
# 	synthesizers
# 	distributive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079576250307958e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
